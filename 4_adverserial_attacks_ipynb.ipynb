# %% [markdown]
# <a href="https://colab.research.google.com/github/mostafa-ja/mal_adv3/blob/main/4_adverserial_attacks_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from scipy import sparse
import gdown
import numpy as np
import matplotlib.pyplot as plt
import pickle
import torch.nn.functional as F
import random
import time

# %%
download_link = 'https://drive.google.com/uc?id=12iud4h19CZst4exbr3U2A9iDxBYvZ5U_'
output_filepath = '/content/'
gdown.download(download_link, output_filepath)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12iud4h19CZst4exbr3U2A9iDxBYvZ5U_
# To: /content/X_redefined_sparse_matrix.npz
# 100%|██████████| 2.31M/2.31M [00:00<00:00, 165MB/s]
# '/content/X_redefined_sparse_matrix.npz'

# %%
download_link = 'https://drive.google.com/uc?id=1IhrcT3jHqlPrw2KvQ5vJkBgozxcJ1cJm'
output_filepath = '/content/'
gdown.download(download_link, output_filepath)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IhrcT3jHqlPrw2KvQ5vJkBgozxcJ1cJm
# To: /content/labels.pt
# 100%|██████████| 517k/517k [00:00<00:00, 59.9MB/s]
# '/content/labels.pt'

# %%
download_link = 'https://drive.google.com/uc?id=13o5n06UpMDOhtk4u7B_RBSWa3kiiGXFs'
output_filepath = '/content/'
gdown.download(download_link, output_filepath)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13o5n06UpMDOhtk4u7B_RBSWa3kiiGXFs
# To: /content/DNN_params.pth
# 100%|██████████| 8.17M/8.17M [00:00<00:00, 59.7MB/s]
# '/content/DNN_params.pth'

# %%
download_link = 'https://drive.google.com/uc?id=1PxFOLBnQAlX-EOsqkhGCSd1T3ykAD0-4'
output_filepath = '/content/'
gdown.download(download_link, output_filepath)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PxFOLBnQAlX-EOsqkhGCSd1T3ykAD0-4
# To: /content/vocab.pkl
# 100%|██████████| 9.18M/9.18M [00:00<00:00, 65.0MB/s]
# '/content/vocab.pkl'

# %%
# Load the dictionary from the file
with open('vocab.pkl', 'rb') as f:
    vocab = pickle.load(f)

for i, (key, value) in enumerate(vocab.items()):
    print((key, value))
    if i >= 5:
        break
# Out:
# ('android/media/mediaplayer->start', 141045)
# ('android/app/activity->setcontentview', 140900)
# ('android/os/vibrator->cancel', 141093)
# ('android.permission.vibrate', 140720)
# ('android.hardware.touchscreen', 137091)
# ('android.intent.action.main', 138335)

# %%
# Load dataset
X_redefined = sparse.load_npz("X_redefined_sparse_matrix.npz")
labels_tensor = torch.load('labels.pt')

# %%
# Split data into train, validation, and test sets with stratified sampling
X_train_val, X_test, labels_train_val, labels_test = train_test_split(X_redefined, labels_tensor, test_size=0.2, stratify=labels_tensor, random_state=42)
X_train, X_val, labels_train, labels_val = train_test_split(X_train_val, labels_train_val, test_size=0.2, stratify=labels_train_val, random_state=42)

# Combine features and labels into datasets
train_dataset = TensorDataset(torch.tensor(X_train.toarray(), dtype=torch.float32), labels_train)
val_dataset = TensorDataset(torch.tensor(X_val.toarray(), dtype=torch.float32), labels_val)
test_dataset = TensorDataset(torch.tensor(X_test.toarray(), dtype=torch.float32), labels_test)

# %%
# Define the DataLoader for training, validation, and test sets
batch_size = 256
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class MalwareDetectionModel(nn.Module):
    def __init__(self, input_size=10000, hidden_1_size=200, hidden_2_size=200, num_labels=2, dropout_prob=0.6):
        super(MalwareDetectionModel, self).__init__()

        self.input_size = input_size
        self.hidden_1_size = hidden_1_size
        self.hidden_2_size = hidden_2_size
        self.num_labels = num_labels
        self.dropout_prob = dropout_prob

        self.fc1 = nn.Linear(input_size, hidden_1_size)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout_prob)
        self.fc2 = nn.Linear(hidden_1_size, hidden_2_size)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout_prob)
        self.fc3 = nn.Linear(hidden_2_size, num_labels)
        self.log_softmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        x = self.log_softmax(x)
        return x

# %%
# Create an instance of your model
model = MalwareDetectionModel()

# Load model parameters
model.load_state_dict(torch.load('DNN_params.pth'))
# Out:
# <All keys matched successfully>

# %%
X,y = next(iter(test_loader))
print(X.shape)
print(y.shape)
# Out:
# torch.Size([256, 10000])
# torch.Size([256, 1])

# %%
len(test_loader)
# Out:
# 101

# %%
torch.manual_seed(0)

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
model = MalwareDetectionModel()

# %%
from adverserial_attacks_functions import *

# %%
def pgd(x, y, model, k=25, step_length=0.02, norm='linf', initial_rounding_threshold=0.5, round_threshold=0.5, random=False, is_report_loss_diff=True, is_sample=False):
    """
    Projected Gradient Descent (PGD) adversarial attack.
    :param y: Ground truth labels
    :param x: Feature vector
    :param model: Neural network model
    :param k: Number of steps
    :param step_length: Step size for each iteration
    :param norm: Norm used for perturbation ('linf' or 'l2')
    :param initial_rounding_threshold: Threshold parameter for rounding the initial x_next
    :param round_threshold: Threshold parameter for rounding
    :param random: Flag to generate random thresholds
    :param is_report_loss_diff: Flag to report loss difference
    :param is_sample: Flag to sample randomly from the feasible area
    :return: The adversarial version of x (tensor)
    """
    model.eval()

    # Compute natural loss
    criterion = nn.CrossEntropyLoss(reduction='none')
    loss_natural = criterion(model(x), y.view(-1).long())

    # Initialize starting point
    x_next = x.clone()
    x_next = get_x0(x_next, initial_rounding_threshold, is_sample)

    # Multi-step PGD
    for t in range(k):
        # Forward pass
        x_var = x_next.clone().detach().requires_grad_(True)
        y_model = model(x_var)
        loss = criterion(y_model, y.view(-1).long())

        # Compute gradient
        grad_vars = torch.autograd.grad(loss.mean(), x_var)
        grad_data = grad_vars[0].data
        gradients = grad_data * (x < 0.5)

        # Norm
        if norm == 'linf':
            perturbation = torch.sign(gradients)
        elif norm == 'l2_2':
            max_grad, _ = gradients.max(dim=1, keepdim=True)
            l2norm = torch.linalg.norm(gradients, dim=-1, keepdim=True)
            #print(max_grad/l2norm)
            perturbation = torch.minimum(torch.tensor(1., dtype=x.dtype, device=x.device), gradients / max_grad)

        elif norm == 'l2':
            l2norm = torch.linalg.norm(gradients, dim=-1, keepdim=True)
            perturbation = torch.minimum(torch.tensor(1., dtype=x.dtype, device=x.device), gradients / l2norm)
            perturbation[torch.isnan(perturbation)] = 0.
            perturbation[torch.isinf(perturbation)] = 1.
        elif norm == 'l1':
            #ignore the gradient of indice which is updated
            gradients = gradients * (x_next < 0.5)
            val, _ = torch.topk(gradients, 1)
            perturbation = (gradients >= val.expand_as(gradients)).float()
            # stop perturbing the examples that are successful to evade the victim
            outputs = model(x_next)
            _, predicted = torch.topk(outputs, k=1)
            done = (predicted != y).squeeze()

            if torch.all(done):
                break
            perturbation[done] = 0.

        else:
            raise ValueError("Expect 'l1' or 'l2' or 'linf' norm.")

        # Update x_next
        x_next = torch.clamp(x_next + perturbation * step_length, min=0., max=1.)

    # Rounding step
    if random:
       round_threshold = torch.rand(x_next.size())
    x_next = round_x(x_next, round_threshold=round_threshold)

    # Feasible projection
    x_next = or_float_tensors(x_next, x)

    # Compute adversarial loss
    loss_adv = criterion(model(x_next), y.view(-1).long()).data

    if is_report_loss_diff:
        outputs = model(x_next)
        _, predicted = torch.topk(outputs, k=1)
        done = (predicted != y).squeeze()
        print(f"PGD {norm}: Attack effectiveness {(done.sum().item() / x.size()[0]) * 100:.3f}%.")

    # Replace with natural if adversarial loss is higher
    replace_flag = (loss_adv < loss_natural).squeeze()
    x_next[replace_flag] = x[replace_flag]

    return x_next

# %%
verbose = True
adv_epochs = 10
lr = 0.001
weight_decay = 0.
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
criterion = nn.CrossEntropyLoss()
total_time = 0.
nbatches = len(train_loader)
best_acc_val = 0.
acc_val_adv_be = 0.
best_epoch = 0

for epoch in range(adv_epochs):
    epoch_losses = []
    epoch_accuracies = []
    for idx_batch, (x_batch, y_batch) in enumerate(train_loader):
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        batch_size = x_batch.shape[0]

        # Separate malicious and benign samples
        mal_x_batch, ben_x_batch = x_batch[y_batch.squeeze() == 1], x_batch[y_batch.squeeze() == 0]
        mal_y_batch, ben_y_batch = y_batch[y_batch.squeeze() == 1], y_batch[y_batch.squeeze() == 0]

        # Generate adversarial examples
        model.eval()
        pertb_mal_x = pgd(mal_x_batch, mal_y_batch, model, k=25, step_length=1., norm='l1', initial_rounding_threshold=0.5, round_threshold=0.5, random=False, is_report_loss_diff=True, is_sample=False)
        x_batch = torch.cat([ben_x_batch, pertb_mal_x], dim=0)
        y_batch = torch.cat([ben_y_batch, mal_y_batch])
        model.train()

        # Forward pass and backward pass
        optimizer.zero_grad()
        outputs = model(x_batch)
        loss_train = criterion(outputs, y_batch.view(-1).long())
        loss_train.backward()
        optimizer.step()

        # Calculate metrics
        epoch_losses.append(loss_train.item())
        _, predicted = torch.topk(outputs, k=1)
        acc_train = (predicted == y_batch).sum().item() / len(y_batch)
        epoch_accuracies.append(acc_train)

        # Print batch level information
        if verbose:
            print(f'Mini batch: {idx_batch + 1}/{nbatches} | Epoch: {epoch + 1}/{adv_epochs} | Batch Loss: {loss_train.item():.4f} | Batch Accuracy: {acc_train * 100:.2f}%')

    # Calculate epoch level metrics
    mean_loss = np.mean(epoch_losses)
    mean_accuracy = np.mean(epoch_accuracies) * 100

    # Print epoch level information
    if verbose:
        print(f'Training loss (epoch level): {mean_loss:.4f} | Train accuracy: {mean_accuracy:.2f}%')

    # Evaluation on validation set
    model.eval()
    avg_acc_ad_val = []
    avg_acc_val = []
    for x_val, y_val in val_loader:
        x_val, y_val = x_val.to(device), y_val.to(device)
        outputs = model(x_val)
        _, predicted = torch.topk(outputs, k=1)
        acc_val = (predicted == y_val).sum().item() / len(y_val)
        avg_acc_val.append(acc_val)

        # Generate adversarial examples for validation set
        mal_x_batch, mal_y_batch = x_val[y_val.squeeze() == 1], y_val[y_val.squeeze() == 1]
        pertb_mal_x = pgd(mal_x_batch, mal_y_batch, model, k=25, step_length=1., norm='l1', initial_rounding_threshold=0.5, round_threshold=0.5, random=False, is_report_loss_diff=True, is_sample=False)
        outputs = model(pertb_mal_x)
        _, y_pred = torch.topk(outputs, k=1)

        acc_ad_val = (y_pred == 1.).sum().item() / len(y_pred)
        avg_acc_ad_val.append(acc_ad_val)


    # Calculate validation accuracy
    assert len(avg_acc_ad_val) > 0
    acc_all = (np.mean(avg_acc_val) + np.mean(avg_acc_ad_val)) / 2.

    # Update best validation accuracy
    if acc_all >= best_acc_val:
        best_acc_val = acc_all
        acc_val_adv_be = np.mean(avg_acc_ad_val)
        best_epoch = epoch + 1

    # Print validation results
    if verbose:
        print(f"\tVal accuracy(without attack) {np.mean(avg_acc_val) * 100:.4}% and accuracy(with attack) {np.mean(avg_acc_ad_val) * 100:.4}% under attack and overall accuracy {acc_all * 100:.4}%.")
        print(f"\tModel select at epoch {best_epoch} with validation accuracy {best_acc_val * 100:.4}% and accuracy {acc_val_adv_be * 100:.4}% under attack.")
# Out:
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 1/323 | Epoch: 1/10 | Batch Loss: 0.0178 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 2/323 | Epoch: 1/10 | Batch Loss: 0.0171 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 3/323 | Epoch: 1/10 | Batch Loss: 0.0300 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 4/323 | Epoch: 1/10 | Batch Loss: 0.0587 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 17.647%.
# Mini batch: 5/323 | Epoch: 1/10 | Batch Loss: 0.1192 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 6/323 | Epoch: 1/10 | Batch Loss: 0.0219 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 38.462%.
# Mini batch: 7/323 | Epoch: 1/10 | Batch Loss: 0.0420 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 8/323 | Epoch: 1/10 | Batch Loss: 0.0439 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 9/323 | Epoch: 1/10 | Batch Loss: 0.1142 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 10/323 | Epoch: 1/10 | Batch Loss: 0.0191 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 11/323 | Epoch: 1/10 | Batch Loss: 0.0636 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 18.750%.
# Mini batch: 12/323 | Epoch: 1/10 | Batch Loss: 0.0290 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 13/323 | Epoch: 1/10 | Batch Loss: 0.0143 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 50.000%.
# Mini batch: 14/323 | Epoch: 1/10 | Batch Loss: 0.0713 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 15/323 | Epoch: 1/10 | Batch Loss: 0.0363 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 16/323 | Epoch: 1/10 | Batch Loss: 0.0448 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 17/323 | Epoch: 1/10 | Batch Loss: 0.0370 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 18/323 | Epoch: 1/10 | Batch Loss: 0.1062 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 19/323 | Epoch: 1/10 | Batch Loss: 0.0810 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 50.000%.
# Mini batch: 20/323 | Epoch: 1/10 | Batch Loss: 0.0920 | Batch Accuracy: 96.88%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 21/323 | Epoch: 1/10 | Batch Loss: 0.0168 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 22/323 | Epoch: 1/10 | Batch Loss: 0.0330 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 44.444%.
# Mini batch: 23/323 | Epoch: 1/10 | Batch Loss: 0.0688 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 24/323 | Epoch: 1/10 | Batch Loss: 0.0387 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 25/323 | Epoch: 1/10 | Batch Loss: 0.0300 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 26/323 | Epoch: 1/10 | Batch Loss: 0.0199 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 27/323 | Epoch: 1/10 | Batch Loss: 0.0217 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 28/323 | Epoch: 1/10 | Batch Loss: 0.0228 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 29/323 | Epoch: 1/10 | Batch Loss: 0.0335 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 30/323 | Epoch: 1/10 | Batch Loss: 0.0462 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 26.667%.
# Mini batch: 31/323 | Epoch: 1/10 | Batch Loss: 0.0521 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 37.500%.
# Mini batch: 32/323 | Epoch: 1/10 | Batch Loss: 0.0211 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 33/323 | Epoch: 1/10 | Batch Loss: 0.0170 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 34/323 | Epoch: 1/10 | Batch Loss: 0.0143 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 40.000%.
# Mini batch: 35/323 | Epoch: 1/10 | Batch Loss: 0.0915 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 36/323 | Epoch: 1/10 | Batch Loss: 0.0225 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 37/323 | Epoch: 1/10 | Batch Loss: 0.0101 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 38/323 | Epoch: 1/10 | Batch Loss: 0.0242 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 39/323 | Epoch: 1/10 | Batch Loss: 0.0270 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 31.250%.
# Mini batch: 40/323 | Epoch: 1/10 | Batch Loss: 0.0680 | Batch Accuracy: 97.27%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 41/323 | Epoch: 1/10 | Batch Loss: 0.0346 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 42/323 | Epoch: 1/10 | Batch Loss: 0.0457 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 43/323 | Epoch: 1/10 | Batch Loss: 0.0128 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 44/323 | Epoch: 1/10 | Batch Loss: 0.0192 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 45/323 | Epoch: 1/10 | Batch Loss: 0.0252 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 46/323 | Epoch: 1/10 | Batch Loss: 0.0764 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 47/323 | Epoch: 1/10 | Batch Loss: 0.0131 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 48/323 | Epoch: 1/10 | Batch Loss: 0.0124 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 49/323 | Epoch: 1/10 | Batch Loss: 0.0620 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 50/323 | Epoch: 1/10 | Batch Loss: 0.0181 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 31.250%.
# Mini batch: 51/323 | Epoch: 1/10 | Batch Loss: 0.0449 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 52/323 | Epoch: 1/10 | Batch Loss: 0.0804 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 53/323 | Epoch: 1/10 | Batch Loss: 0.0176 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 54/323 | Epoch: 1/10 | Batch Loss: 0.0277 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 55/323 | Epoch: 1/10 | Batch Loss: 0.0455 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 56/323 | Epoch: 1/10 | Batch Loss: 0.0421 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 57/323 | Epoch: 1/10 | Batch Loss: 0.0205 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 58/323 | Epoch: 1/10 | Batch Loss: 0.0188 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 59/323 | Epoch: 1/10 | Batch Loss: 0.0164 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 21.429%.
# Mini batch: 60/323 | Epoch: 1/10 | Batch Loss: 0.0633 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 35.714%.
# Mini batch: 61/323 | Epoch: 1/10 | Batch Loss: 0.0282 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 26.667%.
# Mini batch: 62/323 | Epoch: 1/10 | Batch Loss: 0.0301 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 63/323 | Epoch: 1/10 | Batch Loss: 0.0332 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 64/323 | Epoch: 1/10 | Batch Loss: 0.0214 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 65/323 | Epoch: 1/10 | Batch Loss: 0.0185 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 66/323 | Epoch: 1/10 | Batch Loss: 0.0390 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 67/323 | Epoch: 1/10 | Batch Loss: 0.0182 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 68/323 | Epoch: 1/10 | Batch Loss: 0.0606 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 41.667%.
# Mini batch: 69/323 | Epoch: 1/10 | Batch Loss: 0.0468 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 70/323 | Epoch: 1/10 | Batch Loss: 0.0120 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 71/323 | Epoch: 1/10 | Batch Loss: 0.0159 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 72/323 | Epoch: 1/10 | Batch Loss: 0.0339 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 73/323 | Epoch: 1/10 | Batch Loss: 0.0770 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 74/323 | Epoch: 1/10 | Batch Loss: 0.0322 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 36.364%.
# Mini batch: 75/323 | Epoch: 1/10 | Batch Loss: 0.0897 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 76/323 | Epoch: 1/10 | Batch Loss: 0.0397 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 77/323 | Epoch: 1/10 | Batch Loss: 0.0419 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 78/323 | Epoch: 1/10 | Batch Loss: 0.0366 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 79/323 | Epoch: 1/10 | Batch Loss: 0.0365 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 80/323 | Epoch: 1/10 | Batch Loss: 0.0232 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 81/323 | Epoch: 1/10 | Batch Loss: 0.0427 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 82/323 | Epoch: 1/10 | Batch Loss: 0.0765 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 83/323 | Epoch: 1/10 | Batch Loss: 0.0158 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 44.444%.
# Mini batch: 84/323 | Epoch: 1/10 | Batch Loss: 0.0349 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 85/323 | Epoch: 1/10 | Batch Loss: 0.1277 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 86/323 | Epoch: 1/10 | Batch Loss: 0.0667 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 87/323 | Epoch: 1/10 | Batch Loss: 0.0180 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 88/323 | Epoch: 1/10 | Batch Loss: 0.0596 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 89/323 | Epoch: 1/10 | Batch Loss: 0.0120 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 90/323 | Epoch: 1/10 | Batch Loss: 0.0219 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 91/323 | Epoch: 1/10 | Batch Loss: 0.0225 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 92/323 | Epoch: 1/10 | Batch Loss: 0.0219 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 93/323 | Epoch: 1/10 | Batch Loss: 0.0262 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 94/323 | Epoch: 1/10 | Batch Loss: 0.0583 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 95/323 | Epoch: 1/10 | Batch Loss: 0.0153 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 96/323 | Epoch: 1/10 | Batch Loss: 0.0266 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 97/323 | Epoch: 1/10 | Batch Loss: 0.0753 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 98/323 | Epoch: 1/10 | Batch Loss: 0.0719 | Batch Accuracy: 97.27%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 99/323 | Epoch: 1/10 | Batch Loss: 0.0521 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 100/323 | Epoch: 1/10 | Batch Loss: 0.0213 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 101/323 | Epoch: 1/10 | Batch Loss: 0.0748 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 102/323 | Epoch: 1/10 | Batch Loss: 0.0139 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 103/323 | Epoch: 1/10 | Batch Loss: 0.0736 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 40.000%.
# Mini batch: 104/323 | Epoch: 1/10 | Batch Loss: 0.0336 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 105/323 | Epoch: 1/10 | Batch Loss: 0.0068 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 45.455%.
# Mini batch: 106/323 | Epoch: 1/10 | Batch Loss: 0.0477 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 107/323 | Epoch: 1/10 | Batch Loss: 0.0513 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 108/323 | Epoch: 1/10 | Batch Loss: 0.0491 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 109/323 | Epoch: 1/10 | Batch Loss: 0.0212 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 40.000%.
# Mini batch: 110/323 | Epoch: 1/10 | Batch Loss: 0.0292 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 111/323 | Epoch: 1/10 | Batch Loss: 0.0209 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 15.789%.
# Mini batch: 112/323 | Epoch: 1/10 | Batch Loss: 0.0367 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 113/323 | Epoch: 1/10 | Batch Loss: 0.0553 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 114/323 | Epoch: 1/10 | Batch Loss: 0.0163 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 115/323 | Epoch: 1/10 | Batch Loss: 0.0247 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 116/323 | Epoch: 1/10 | Batch Loss: 0.0173 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 117/323 | Epoch: 1/10 | Batch Loss: 0.0195 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 118/323 | Epoch: 1/10 | Batch Loss: 0.0151 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 119/323 | Epoch: 1/10 | Batch Loss: 0.0109 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 120/323 | Epoch: 1/10 | Batch Loss: 0.0102 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 45.455%.
# Mini batch: 121/323 | Epoch: 1/10 | Batch Loss: 0.0353 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 37.500%.
# Mini batch: 122/323 | Epoch: 1/10 | Batch Loss: 0.0351 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 123/323 | Epoch: 1/10 | Batch Loss: 0.0217 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 5.882%.
# Mini batch: 124/323 | Epoch: 1/10 | Batch Loss: 0.0260 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 125/323 | Epoch: 1/10 | Batch Loss: 0.0160 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 126/323 | Epoch: 1/10 | Batch Loss: 0.0238 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 127/323 | Epoch: 1/10 | Batch Loss: 0.0153 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 128/323 | Epoch: 1/10 | Batch Loss: 0.0476 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 129/323 | Epoch: 1/10 | Batch Loss: 0.0211 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 130/323 | Epoch: 1/10 | Batch Loss: 0.0755 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 5.263%.
# Mini batch: 131/323 | Epoch: 1/10 | Batch Loss: 0.0506 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 132/323 | Epoch: 1/10 | Batch Loss: 0.0267 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 133/323 | Epoch: 1/10 | Batch Loss: 0.0510 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 134/323 | Epoch: 1/10 | Batch Loss: 0.0381 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 135/323 | Epoch: 1/10 | Batch Loss: 0.0272 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 136/323 | Epoch: 1/10 | Batch Loss: 0.0396 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 137/323 | Epoch: 1/10 | Batch Loss: 0.0324 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 138/323 | Epoch: 1/10 | Batch Loss: 0.0532 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 139/323 | Epoch: 1/10 | Batch Loss: 0.0625 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 140/323 | Epoch: 1/10 | Batch Loss: 0.0231 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 141/323 | Epoch: 1/10 | Batch Loss: 0.0182 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 142/323 | Epoch: 1/10 | Batch Loss: 0.0153 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 143/323 | Epoch: 1/10 | Batch Loss: 0.0594 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 144/323 | Epoch: 1/10 | Batch Loss: 0.0129 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 145/323 | Epoch: 1/10 | Batch Loss: 0.0386 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 17.647%.
# Mini batch: 146/323 | Epoch: 1/10 | Batch Loss: 0.0411 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 147/323 | Epoch: 1/10 | Batch Loss: 0.0240 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 148/323 | Epoch: 1/10 | Batch Loss: 0.0241 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 149/323 | Epoch: 1/10 | Batch Loss: 0.0067 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 150/323 | Epoch: 1/10 | Batch Loss: 0.0156 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 151/323 | Epoch: 1/10 | Batch Loss: 0.0296 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 152/323 | Epoch: 1/10 | Batch Loss: 0.0182 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 153/323 | Epoch: 1/10 | Batch Loss: 0.0655 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 154/323 | Epoch: 1/10 | Batch Loss: 0.0514 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 155/323 | Epoch: 1/10 | Batch Loss: 0.0093 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 156/323 | Epoch: 1/10 | Batch Loss: 0.0078 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 157/323 | Epoch: 1/10 | Batch Loss: 0.0170 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 29.412%.
# Mini batch: 158/323 | Epoch: 1/10 | Batch Loss: 0.0415 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 159/323 | Epoch: 1/10 | Batch Loss: 0.0257 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 160/323 | Epoch: 1/10 | Batch Loss: 0.0245 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 36.364%.
# Mini batch: 161/323 | Epoch: 1/10 | Batch Loss: 0.0515 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 162/323 | Epoch: 1/10 | Batch Loss: 0.0732 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 18.750%.
# Mini batch: 163/323 | Epoch: 1/10 | Batch Loss: 0.0207 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 164/323 | Epoch: 1/10 | Batch Loss: 0.0120 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 165/323 | Epoch: 1/10 | Batch Loss: 0.0296 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 166/323 | Epoch: 1/10 | Batch Loss: 0.0342 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 167/323 | Epoch: 1/10 | Batch Loss: 0.0193 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 168/323 | Epoch: 1/10 | Batch Loss: 0.0343 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 169/323 | Epoch: 1/10 | Batch Loss: 0.0115 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 170/323 | Epoch: 1/10 | Batch Loss: 0.0144 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 171/323 | Epoch: 1/10 | Batch Loss: 0.0060 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 172/323 | Epoch: 1/10 | Batch Loss: 0.0348 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 173/323 | Epoch: 1/10 | Batch Loss: 0.0170 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 174/323 | Epoch: 1/10 | Batch Loss: 0.0222 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 175/323 | Epoch: 1/10 | Batch Loss: 0.0186 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 176/323 | Epoch: 1/10 | Batch Loss: 0.0236 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 177/323 | Epoch: 1/10 | Batch Loss: 0.0126 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 178/323 | Epoch: 1/10 | Batch Loss: 0.0148 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 179/323 | Epoch: 1/10 | Batch Loss: 0.0169 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 180/323 | Epoch: 1/10 | Batch Loss: 0.0268 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 181/323 | Epoch: 1/10 | Batch Loss: 0.0342 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 26.667%.
# Mini batch: 182/323 | Epoch: 1/10 | Batch Loss: 0.0226 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 183/323 | Epoch: 1/10 | Batch Loss: 0.0217 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 37.500%.
# Mini batch: 184/323 | Epoch: 1/10 | Batch Loss: 0.0658 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 185/323 | Epoch: 1/10 | Batch Loss: 0.0203 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 186/323 | Epoch: 1/10 | Batch Loss: 0.0200 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 187/323 | Epoch: 1/10 | Batch Loss: 0.0167 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 188/323 | Epoch: 1/10 | Batch Loss: 0.0108 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 189/323 | Epoch: 1/10 | Batch Loss: 0.0099 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 190/323 | Epoch: 1/10 | Batch Loss: 0.0322 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 191/323 | Epoch: 1/10 | Batch Loss: 0.0257 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 192/323 | Epoch: 1/10 | Batch Loss: 0.0053 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 18.750%.
# Mini batch: 193/323 | Epoch: 1/10 | Batch Loss: 0.0356 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 194/323 | Epoch: 1/10 | Batch Loss: 0.0326 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 21.429%.
# Mini batch: 195/323 | Epoch: 1/10 | Batch Loss: 0.0407 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 196/323 | Epoch: 1/10 | Batch Loss: 0.2096 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 197/323 | Epoch: 1/10 | Batch Loss: 0.0224 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 198/323 | Epoch: 1/10 | Batch Loss: 0.0195 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 11.765%.
# Mini batch: 199/323 | Epoch: 1/10 | Batch Loss: 0.0194 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 36.364%.
# Mini batch: 200/323 | Epoch: 1/10 | Batch Loss: 0.0513 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 29.412%.
# Mini batch: 201/323 | Epoch: 1/10 | Batch Loss: 0.0262 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 202/323 | Epoch: 1/10 | Batch Loss: 0.0211 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 203/323 | Epoch: 1/10 | Batch Loss: 0.0466 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 204/323 | Epoch: 1/10 | Batch Loss: 0.0316 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 205/323 | Epoch: 1/10 | Batch Loss: 0.0259 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 206/323 | Epoch: 1/10 | Batch Loss: 0.1026 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 207/323 | Epoch: 1/10 | Batch Loss: 0.0721 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 208/323 | Epoch: 1/10 | Batch Loss: 0.0258 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 209/323 | Epoch: 1/10 | Batch Loss: 0.0459 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 210/323 | Epoch: 1/10 | Batch Loss: 0.0388 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 211/323 | Epoch: 1/10 | Batch Loss: 0.0375 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 212/323 | Epoch: 1/10 | Batch Loss: 0.0513 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 40.000%.
# Mini batch: 213/323 | Epoch: 1/10 | Batch Loss: 0.0390 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 214/323 | Epoch: 1/10 | Batch Loss: 0.0755 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 215/323 | Epoch: 1/10 | Batch Loss: 0.0405 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 37.500%.
# Mini batch: 216/323 | Epoch: 1/10 | Batch Loss: 0.0398 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 217/323 | Epoch: 1/10 | Batch Loss: 0.0456 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 37.500%.
# Mini batch: 218/323 | Epoch: 1/10 | Batch Loss: 0.0212 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 219/323 | Epoch: 1/10 | Batch Loss: 0.0375 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 220/323 | Epoch: 1/10 | Batch Loss: 0.0171 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 221/323 | Epoch: 1/10 | Batch Loss: 0.0138 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 222/323 | Epoch: 1/10 | Batch Loss: 0.0608 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 223/323 | Epoch: 1/10 | Batch Loss: 0.0111 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 224/323 | Epoch: 1/10 | Batch Loss: 0.0469 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 225/323 | Epoch: 1/10 | Batch Loss: 0.0139 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 226/323 | Epoch: 1/10 | Batch Loss: 0.0277 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 227/323 | Epoch: 1/10 | Batch Loss: 0.0464 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 228/323 | Epoch: 1/10 | Batch Loss: 0.0256 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 229/323 | Epoch: 1/10 | Batch Loss: 0.0345 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 230/323 | Epoch: 1/10 | Batch Loss: 0.0378 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 231/323 | Epoch: 1/10 | Batch Loss: 0.0133 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 232/323 | Epoch: 1/10 | Batch Loss: 0.0163 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 233/323 | Epoch: 1/10 | Batch Loss: 0.0087 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 21.053%.
# Mini batch: 234/323 | Epoch: 1/10 | Batch Loss: 0.0225 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 235/323 | Epoch: 1/10 | Batch Loss: 0.0104 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 236/323 | Epoch: 1/10 | Batch Loss: 0.0137 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 237/323 | Epoch: 1/10 | Batch Loss: 0.0107 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 238/323 | Epoch: 1/10 | Batch Loss: 0.0274 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 239/323 | Epoch: 1/10 | Batch Loss: 0.0166 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 240/323 | Epoch: 1/10 | Batch Loss: 0.0239 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 241/323 | Epoch: 1/10 | Batch Loss: 0.0122 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 242/323 | Epoch: 1/10 | Batch Loss: 0.0543 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 243/323 | Epoch: 1/10 | Batch Loss: 0.0040 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 244/323 | Epoch: 1/10 | Batch Loss: 0.0326 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 245/323 | Epoch: 1/10 | Batch Loss: 0.0098 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 246/323 | Epoch: 1/10 | Batch Loss: 0.0354 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 247/323 | Epoch: 1/10 | Batch Loss: 0.0480 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 248/323 | Epoch: 1/10 | Batch Loss: 0.0338 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 249/323 | Epoch: 1/10 | Batch Loss: 0.0163 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 250/323 | Epoch: 1/10 | Batch Loss: 0.0285 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 251/323 | Epoch: 1/10 | Batch Loss: 0.0137 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 252/323 | Epoch: 1/10 | Batch Loss: 0.0200 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 253/323 | Epoch: 1/10 | Batch Loss: 0.0806 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 254/323 | Epoch: 1/10 | Batch Loss: 0.0206 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 255/323 | Epoch: 1/10 | Batch Loss: 0.0650 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 256/323 | Epoch: 1/10 | Batch Loss: 0.0275 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 257/323 | Epoch: 1/10 | Batch Loss: 0.0561 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 258/323 | Epoch: 1/10 | Batch Loss: 0.0436 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 259/323 | Epoch: 1/10 | Batch Loss: 0.0196 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 260/323 | Epoch: 1/10 | Batch Loss: 0.0652 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 261/323 | Epoch: 1/10 | Batch Loss: 0.0092 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 26.667%.
# Mini batch: 262/323 | Epoch: 1/10 | Batch Loss: 0.0264 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 263/323 | Epoch: 1/10 | Batch Loss: 0.0741 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 264/323 | Epoch: 1/10 | Batch Loss: 0.0108 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 265/323 | Epoch: 1/10 | Batch Loss: 0.0274 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 266/323 | Epoch: 1/10 | Batch Loss: 0.0498 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 267/323 | Epoch: 1/10 | Batch Loss: 0.0161 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 268/323 | Epoch: 1/10 | Batch Loss: 0.0720 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 36.364%.
# Mini batch: 269/323 | Epoch: 1/10 | Batch Loss: 0.0231 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 270/323 | Epoch: 1/10 | Batch Loss: 0.0400 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 271/323 | Epoch: 1/10 | Batch Loss: 0.0106 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 272/323 | Epoch: 1/10 | Batch Loss: 0.0398 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 273/323 | Epoch: 1/10 | Batch Loss: 0.0533 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 23.529%.
# Mini batch: 274/323 | Epoch: 1/10 | Batch Loss: 0.0835 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 275/323 | Epoch: 1/10 | Batch Loss: 0.0189 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 40.000%.
# Mini batch: 276/323 | Epoch: 1/10 | Batch Loss: 0.0308 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 277/323 | Epoch: 1/10 | Batch Loss: 0.0432 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 35.714%.
# Mini batch: 278/323 | Epoch: 1/10 | Batch Loss: 0.0897 | Batch Accuracy: 97.27%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 279/323 | Epoch: 1/10 | Batch Loss: 0.0219 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 280/323 | Epoch: 1/10 | Batch Loss: 0.0172 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 281/323 | Epoch: 1/10 | Batch Loss: 0.0134 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 282/323 | Epoch: 1/10 | Batch Loss: 0.0541 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 36.364%.
# Mini batch: 283/323 | Epoch: 1/10 | Batch Loss: 0.0239 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 284/323 | Epoch: 1/10 | Batch Loss: 0.0114 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 18.750%.
# Mini batch: 285/323 | Epoch: 1/10 | Batch Loss: 0.0890 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 286/323 | Epoch: 1/10 | Batch Loss: 0.0433 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 287/323 | Epoch: 1/10 | Batch Loss: 0.0206 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 288/323 | Epoch: 1/10 | Batch Loss: 0.0288 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 36.364%.
# Mini batch: 289/323 | Epoch: 1/10 | Batch Loss: 0.0304 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 290/323 | Epoch: 1/10 | Batch Loss: 0.0424 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 291/323 | Epoch: 1/10 | Batch Loss: 0.0181 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 292/323 | Epoch: 1/10 | Batch Loss: 0.0105 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 293/323 | Epoch: 1/10 | Batch Loss: 0.0326 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 294/323 | Epoch: 1/10 | Batch Loss: 0.0225 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 295/323 | Epoch: 1/10 | Batch Loss: 0.0293 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 296/323 | Epoch: 1/10 | Batch Loss: 0.0343 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 297/323 | Epoch: 1/10 | Batch Loss: 0.0272 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 21.429%.
# Mini batch: 298/323 | Epoch: 1/10 | Batch Loss: 0.0374 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 299/323 | Epoch: 1/10 | Batch Loss: 0.0460 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 300/323 | Epoch: 1/10 | Batch Loss: 0.0180 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 301/323 | Epoch: 1/10 | Batch Loss: 0.0352 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 302/323 | Epoch: 1/10 | Batch Loss: 0.0369 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 303/323 | Epoch: 1/10 | Batch Loss: 0.0393 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 304/323 | Epoch: 1/10 | Batch Loss: 0.0240 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 305/323 | Epoch: 1/10 | Batch Loss: 0.0205 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 306/323 | Epoch: 1/10 | Batch Loss: 0.0247 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 21.053%.
# Mini batch: 307/323 | Epoch: 1/10 | Batch Loss: 0.1019 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 308/323 | Epoch: 1/10 | Batch Loss: 0.0096 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 11.765%.
# Mini batch: 309/323 | Epoch: 1/10 | Batch Loss: 0.0663 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 310/323 | Epoch: 1/10 | Batch Loss: 0.0112 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 311/323 | Epoch: 1/10 | Batch Loss: 0.0459 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 312/323 | Epoch: 1/10 | Batch Loss: 0.0450 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 313/323 | Epoch: 1/10 | Batch Loss: 0.0520 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 314/323 | Epoch: 1/10 | Batch Loss: 0.0492 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 315/323 | Epoch: 1/10 | Batch Loss: 0.0677 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 316/323 | Epoch: 1/10 | Batch Loss: 0.0269 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 317/323 | Epoch: 1/10 | Batch Loss: 0.0399 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 318/323 | Epoch: 1/10 | Batch Loss: 0.0241 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 319/323 | Epoch: 1/10 | Batch Loss: 0.0270 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 320/323 | Epoch: 1/10 | Batch Loss: 0.0191 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 321/323 | Epoch: 1/10 | Batch Loss: 0.0290 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 322/323 | Epoch: 1/10 | Batch Loss: 0.0374 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 323/323 | Epoch: 1/10 | Batch Loss: 0.0301 | Batch Accuracy: 98.53%
# Training loss (epoch level): 0.0353 | Train accuracy: 99.02%
# PGD l1: Attack effectiveness 9.091%.
# PGD l1: Attack effectiveness 25.000%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 27.273%.
# PGD l1: Attack effectiveness 22.222%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 16.667%.
# PGD l1: Attack effectiveness 11.111%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 9.091%.
# PGD l1: Attack effectiveness 7.143%.
# PGD l1: Attack effectiveness 23.077%.
# PGD l1: Attack effectiveness 12.500%.
# PGD l1: Attack effectiveness 26.667%.
# PGD l1: Attack effectiveness 20.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 5.556%.
# PGD l1: Attack effectiveness 22.222%.
# PGD l1: Attack effectiveness 27.273%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 22.222%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 7.692%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 14.286%.
# PGD l1: Attack effectiveness 11.111%.
# PGD l1: Attack effectiveness 22.222%.
# PGD l1: Attack effectiveness 42.857%.
# PGD l1: Attack effectiveness 7.143%.
# PGD l1: Attack effectiveness 21.429%.
# PGD l1: Attack effectiveness 11.765%.
# PGD l1: Attack effectiveness 21.429%.
# PGD l1: Attack effectiveness 7.692%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 50.000%.
# PGD l1: Attack effectiveness 16.667%.
# PGD l1: Attack effectiveness 9.091%.
# PGD l1: Attack effectiveness 9.091%.
# PGD l1: Attack effectiveness 36.364%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 22.222%.
# PGD l1: Attack effectiveness 20.000%.
# PGD l1: Attack effectiveness 14.286%.
# PGD l1: Attack effectiveness 9.091%.
# PGD l1: Attack effectiveness 4.762%.
# PGD l1: Attack effectiveness 10.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 14.286%.
# PGD l1: Attack effectiveness 12.500%.
# PGD l1: Attack effectiveness 9.091%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 50.000%.
# PGD l1: Attack effectiveness 7.143%.
# PGD l1: Attack effectiveness 20.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 21.429%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 8.333%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 13.333%.
# PGD l1: Attack effectiveness 14.286%.
# PGD l1: Attack effectiveness 14.286%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 10.000%.
# PGD l1: Attack effectiveness 30.000%.
# PGD l1: Attack effectiveness 11.111%.
# PGD l1: Attack effectiveness 16.667%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 0.000%.
# PGD l1: Attack effectiveness 10.000%.
# PGD l1: Attack effectiveness 33.333%.
# 	Val accuracy(without attack) 99.57% and accuracy(with attack) 87.63% under attack and overall accuracy 93.6%.
# 	Model select at epoch 1 with validation accuracy 93.6% and accuracy 87.63% under attack.
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 1/323 | Epoch: 2/10 | Batch Loss: 0.0577 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 2/323 | Epoch: 2/10 | Batch Loss: 0.0386 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 3/323 | Epoch: 2/10 | Batch Loss: 0.0526 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 4/323 | Epoch: 2/10 | Batch Loss: 0.0435 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 5/323 | Epoch: 2/10 | Batch Loss: 0.0462 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 6/323 | Epoch: 2/10 | Batch Loss: 0.0269 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 7/323 | Epoch: 2/10 | Batch Loss: 0.0078 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 8/323 | Epoch: 2/10 | Batch Loss: 0.0352 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 9/323 | Epoch: 2/10 | Batch Loss: 0.0181 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 10/323 | Epoch: 2/10 | Batch Loss: 0.0352 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 11/323 | Epoch: 2/10 | Batch Loss: 0.0183 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 12/323 | Epoch: 2/10 | Batch Loss: 0.0492 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 13/323 | Epoch: 2/10 | Batch Loss: 0.0460 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 14/323 | Epoch: 2/10 | Batch Loss: 0.0194 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 15/323 | Epoch: 2/10 | Batch Loss: 0.0346 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 17.647%.
# Mini batch: 16/323 | Epoch: 2/10 | Batch Loss: 0.0354 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 17/323 | Epoch: 2/10 | Batch Loss: 0.0249 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 18/323 | Epoch: 2/10 | Batch Loss: 0.0517 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 19/323 | Epoch: 2/10 | Batch Loss: 0.0872 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 20/323 | Epoch: 2/10 | Batch Loss: 0.0328 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 21/323 | Epoch: 2/10 | Batch Loss: 0.0179 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 22/323 | Epoch: 2/10 | Batch Loss: 0.0225 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 23/323 | Epoch: 2/10 | Batch Loss: 0.0188 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 24/323 | Epoch: 2/10 | Batch Loss: 0.0329 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 25/323 | Epoch: 2/10 | Batch Loss: 0.0329 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 26/323 | Epoch: 2/10 | Batch Loss: 0.0176 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 41.667%.
# Mini batch: 27/323 | Epoch: 2/10 | Batch Loss: 0.0513 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 28/323 | Epoch: 2/10 | Batch Loss: 0.0135 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 29/323 | Epoch: 2/10 | Batch Loss: 0.0107 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 30/323 | Epoch: 2/10 | Batch Loss: 0.0468 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 31/323 | Epoch: 2/10 | Batch Loss: 0.0331 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 18.750%.
# Mini batch: 32/323 | Epoch: 2/10 | Batch Loss: 0.0159 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 33/323 | Epoch: 2/10 | Batch Loss: 0.0147 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 50.000%.
# Mini batch: 34/323 | Epoch: 2/10 | Batch Loss: 0.0682 | Batch Accuracy: 97.66%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 35/323 | Epoch: 2/10 | Batch Loss: 0.0210 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 36/323 | Epoch: 2/10 | Batch Loss: 0.0093 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 37/323 | Epoch: 2/10 | Batch Loss: 0.0115 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 38/323 | Epoch: 2/10 | Batch Loss: 0.0340 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 13.333%.
# Mini batch: 39/323 | Epoch: 2/10 | Batch Loss: 0.0253 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 40/323 | Epoch: 2/10 | Batch Loss: 0.0259 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 41/323 | Epoch: 2/10 | Batch Loss: 0.0621 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 42/323 | Epoch: 2/10 | Batch Loss: 0.0174 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 43/323 | Epoch: 2/10 | Batch Loss: 0.0455 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 44/323 | Epoch: 2/10 | Batch Loss: 0.0533 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 45/323 | Epoch: 2/10 | Batch Loss: 0.0202 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 46/323 | Epoch: 2/10 | Batch Loss: 0.0398 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 47/323 | Epoch: 2/10 | Batch Loss: 0.0042 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 48/323 | Epoch: 2/10 | Batch Loss: 0.0549 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 49/323 | Epoch: 2/10 | Batch Loss: 0.0167 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 50/323 | Epoch: 2/10 | Batch Loss: 0.0335 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 51/323 | Epoch: 2/10 | Batch Loss: 0.0105 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 52/323 | Epoch: 2/10 | Batch Loss: 0.0178 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 53/323 | Epoch: 2/10 | Batch Loss: 0.0262 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 54/323 | Epoch: 2/10 | Batch Loss: 0.0386 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 55/323 | Epoch: 2/10 | Batch Loss: 0.0210 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 56/323 | Epoch: 2/10 | Batch Loss: 0.0169 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 57/323 | Epoch: 2/10 | Batch Loss: 0.0506 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 58/323 | Epoch: 2/10 | Batch Loss: 0.0117 | Batch Accuracy: 99.22%
# ...
# Mini batch: 87/323 | Epoch: 4/10 | Batch Loss: 0.0210 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 88/323 | Epoch: 4/10 | Batch Loss: 0.0063 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 89/323 | Epoch: 4/10 | Batch Loss: 0.0465 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 90/323 | Epoch: 4/10 | Batch Loss: 0.0287 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 91/323 | Epoch: 4/10 | Batch Loss: 0.0292 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 92/323 | Epoch: 4/10 | Batch Loss: 0.0256 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 93/323 | Epoch: 4/10 | Batch Loss: 0.0088 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 94/323 | Epoch: 4/10 | Batch Loss: 0.0057 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 95/323 | Epoch: 4/10 | Batch Loss: 0.0279 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 96/323 | Epoch: 4/10 | Batch Loss: 0.0523 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 97/323 | Epoch: 4/10 | Batch Loss: 0.0155 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 98/323 | Epoch: 4/10 | Batch Loss: 0.0211 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 99/323 | Epoch: 4/10 | Batch Loss: 0.0056 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 5.882%.
# Mini batch: 100/323 | Epoch: 4/10 | Batch Loss: 0.0208 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 11.765%.
# Mini batch: 101/323 | Epoch: 4/10 | Batch Loss: 0.0268 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 30.769%.
# Mini batch: 102/323 | Epoch: 4/10 | Batch Loss: 0.0348 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 103/323 | Epoch: 4/10 | Batch Loss: 0.0132 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 10.526%.
# Mini batch: 104/323 | Epoch: 4/10 | Batch Loss: 0.0231 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 105/323 | Epoch: 4/10 | Batch Loss: 0.0053 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 106/323 | Epoch: 4/10 | Batch Loss: 0.0057 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 107/323 | Epoch: 4/10 | Batch Loss: 0.0185 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 42.857%.
# Mini batch: 108/323 | Epoch: 4/10 | Batch Loss: 0.0457 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 109/323 | Epoch: 4/10 | Batch Loss: 0.0200 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 110/323 | Epoch: 4/10 | Batch Loss: 0.0282 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 111/323 | Epoch: 4/10 | Batch Loss: 0.0408 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 112/323 | Epoch: 4/10 | Batch Loss: 0.0999 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 113/323 | Epoch: 4/10 | Batch Loss: 0.0170 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 114/323 | Epoch: 4/10 | Batch Loss: 0.0169 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 115/323 | Epoch: 4/10 | Batch Loss: 0.0057 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 116/323 | Epoch: 4/10 | Batch Loss: 0.0440 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 117/323 | Epoch: 4/10 | Batch Loss: 0.0183 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 118/323 | Epoch: 4/10 | Batch Loss: 0.0097 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 119/323 | Epoch: 4/10 | Batch Loss: 0.0431 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 120/323 | Epoch: 4/10 | Batch Loss: 0.0233 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 121/323 | Epoch: 4/10 | Batch Loss: 0.0255 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.143%.
# Mini batch: 122/323 | Epoch: 4/10 | Batch Loss: 0.0129 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 123/323 | Epoch: 4/10 | Batch Loss: 0.0180 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 124/323 | Epoch: 4/10 | Batch Loss: 0.0152 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 125/323 | Epoch: 4/10 | Batch Loss: 0.0099 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 126/323 | Epoch: 4/10 | Batch Loss: 0.0155 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 127/323 | Epoch: 4/10 | Batch Loss: 0.0454 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 128/323 | Epoch: 4/10 | Batch Loss: 0.0233 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 11.765%.
# Mini batch: 129/323 | Epoch: 4/10 | Batch Loss: 0.0326 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 17.647%.
# Mini batch: 130/323 | Epoch: 4/10 | Batch Loss: 0.0390 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 131/323 | Epoch: 4/10 | Batch Loss: 0.0423 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 22.222%.
# Mini batch: 132/323 | Epoch: 4/10 | Batch Loss: 0.0381 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 133/323 | Epoch: 4/10 | Batch Loss: 0.0136 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 134/323 | Epoch: 4/10 | Batch Loss: 0.0245 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 14.286%.
# Mini batch: 135/323 | Epoch: 4/10 | Batch Loss: 0.0534 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 136/323 | Epoch: 4/10 | Batch Loss: 0.0300 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 137/323 | Epoch: 4/10 | Batch Loss: 0.0064 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 138/323 | Epoch: 4/10 | Batch Loss: 0.0239 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 139/323 | Epoch: 4/10 | Batch Loss: 0.0298 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 5.882%.
# Mini batch: 140/323 | Epoch: 4/10 | Batch Loss: 0.0163 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 141/323 | Epoch: 4/10 | Batch Loss: 0.0129 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 142/323 | Epoch: 4/10 | Batch Loss: 0.0082 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 143/323 | Epoch: 4/10 | Batch Loss: 0.0354 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 144/323 | Epoch: 4/10 | Batch Loss: 0.0193 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 27.273%.
# Mini batch: 145/323 | Epoch: 4/10 | Batch Loss: 0.0313 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 21.429%.
# Mini batch: 146/323 | Epoch: 4/10 | Batch Loss: 0.0455 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 147/323 | Epoch: 4/10 | Batch Loss: 0.0115 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 148/323 | Epoch: 4/10 | Batch Loss: 0.0196 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 149/323 | Epoch: 4/10 | Batch Loss: 0.0178 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 150/323 | Epoch: 4/10 | Batch Loss: 0.0404 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 151/323 | Epoch: 4/10 | Batch Loss: 0.0200 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 152/323 | Epoch: 4/10 | Batch Loss: 0.0618 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 153/323 | Epoch: 4/10 | Batch Loss: 0.0503 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 9.091%.
# Mini batch: 154/323 | Epoch: 4/10 | Batch Loss: 0.0424 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 6.250%.
# Mini batch: 155/323 | Epoch: 4/10 | Batch Loss: 0.0185 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 156/323 | Epoch: 4/10 | Batch Loss: 0.0378 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 157/323 | Epoch: 4/10 | Batch Loss: 0.0105 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 158/323 | Epoch: 4/10 | Batch Loss: 0.0034 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 159/323 | Epoch: 4/10 | Batch Loss: 0.0056 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 160/323 | Epoch: 4/10 | Batch Loss: 0.0255 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 161/323 | Epoch: 4/10 | Batch Loss: 0.0275 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 28.571%.
# Mini batch: 162/323 | Epoch: 4/10 | Batch Loss: 0.0443 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 163/323 | Epoch: 4/10 | Batch Loss: 0.0174 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 164/323 | Epoch: 4/10 | Batch Loss: 0.0072 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 35.714%.
# Mini batch: 165/323 | Epoch: 4/10 | Batch Loss: 0.0764 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 33.333%.
# Mini batch: 166/323 | Epoch: 4/10 | Batch Loss: 0.0470 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 167/323 | Epoch: 4/10 | Batch Loss: 0.0215 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 168/323 | Epoch: 4/10 | Batch Loss: 0.0254 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 169/323 | Epoch: 4/10 | Batch Loss: 0.0190 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 170/323 | Epoch: 4/10 | Batch Loss: 0.0301 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 171/323 | Epoch: 4/10 | Batch Loss: 0.0226 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 7.692%.
# Mini batch: 172/323 | Epoch: 4/10 | Batch Loss: 0.0154 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 173/323 | Epoch: 4/10 | Batch Loss: 0.0133 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 174/323 | Epoch: 4/10 | Batch Loss: 0.0158 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 175/323 | Epoch: 4/10 | Batch Loss: 0.0137 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 18.750%.
# Mini batch: 176/323 | Epoch: 4/10 | Batch Loss: 0.0421 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 177/323 | Epoch: 4/10 | Batch Loss: 0.0329 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 178/323 | Epoch: 4/10 | Batch Loss: 0.0381 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 179/323 | Epoch: 4/10 | Batch Loss: 0.0110 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 180/323 | Epoch: 4/10 | Batch Loss: 0.0129 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 15.385%.
# Mini batch: 181/323 | Epoch: 4/10 | Batch Loss: 0.0292 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 182/323 | Epoch: 4/10 | Batch Loss: 0.0751 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 183/323 | Epoch: 4/10 | Batch Loss: 0.0102 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 11.111%.
# Mini batch: 184/323 | Epoch: 4/10 | Batch Loss: 0.0283 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 185/323 | Epoch: 4/10 | Batch Loss: 0.0081 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 186/323 | Epoch: 4/10 | Batch Loss: 0.0301 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 10.000%.
# Mini batch: 187/323 | Epoch: 4/10 | Batch Loss: 0.0189 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 188/323 | Epoch: 4/10 | Batch Loss: 0.0071 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 30.000%.
# Mini batch: 189/323 | Epoch: 4/10 | Batch Loss: 0.0309 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 6.667%.
# Mini batch: 190/323 | Epoch: 4/10 | Batch Loss: 0.0061 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 37.500%.
# Mini batch: 191/323 | Epoch: 4/10 | Batch Loss: 0.0464 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 8.333%.
# Mini batch: 192/323 | Epoch: 4/10 | Batch Loss: 0.0375 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 193/323 | Epoch: 4/10 | Batch Loss: 0.0161 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 194/323 | Epoch: 4/10 | Batch Loss: 0.0260 | Batch Accuracy: 98.05%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 195/323 | Epoch: 4/10 | Batch Loss: 0.0089 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 18.182%.
# Mini batch: 196/323 | Epoch: 4/10 | Batch Loss: 0.0206 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 25.000%.
# Mini batch: 197/323 | Epoch: 4/10 | Batch Loss: 0.0617 | Batch Accuracy: 98.83%
# PGD l1: Attack effectiveness 23.077%.
# Mini batch: 198/323 | Epoch: 4/10 | Batch Loss: 0.0556 | Batch Accuracy: 98.44%
# PGD l1: Attack effectiveness 12.500%.
# Mini batch: 199/323 | Epoch: 4/10 | Batch Loss: 0.0280 | Batch Accuracy: 99.22%
# PGD l1: Attack effectiveness 0.000%.
# Mini batch: 200/323 | Epoch: 4/10 | Batch Loss: 0.0079 | Batch Accuracy: 100.00%
# PGD l1: Attack effectiveness 16.667%.
# Mini batch: 201/323 | Epoch: 4/10 | Batch Loss: 0.0159 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 20.000%.
# Mini batch: 202/323 | Epoch: 4/10 | Batch Loss: 0.0177 | Batch Accuracy: 99.61%
# PGD l1: Attack effectiveness 0.000%.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-490be0dfa6ca> in <cell line: 13>()
#      31         # Forward pass and backward pass
#      32         optimizer.zero_grad()
# ---> 33         outputs = model(x_batch)
#      34         loss_train = criterion(outputs, y_batch.view(-1).long())
#      35         loss_train.backward()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-1-6db1bf490d36> in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         x = self.fc1(x)
#      25         x = self.relu1(x)
#      26         x = self.dropout1(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
